# %% [markdown]
# # Phase 1 Data Exploration
#
# Use this notebook to inspect the raw datasets, clean the data, and generate initial outputs for the hackathon.

# %%
from pathlib import Path

import pandas as pd

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
project_root
